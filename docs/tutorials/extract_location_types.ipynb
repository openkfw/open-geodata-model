# %% [markdown]
# # Location type from excel
#
# In this notebook we extract the location type from the excel template and compare them to the IATI standard.
#
# The IATI standard we use is:
#
# - Location type and it can be pulled from [here](https://iatistandard.org/en/iati-standard/203/codelists/locationtype/)
#
# First let us get the data from the IATI standard

# %%
import json
from pprint import pprint

# first load the external reference provided by IATI
file_path = "../../external/iati_location_type_v2_0_3.json"

with open(file_path, encoding="utf-8") as f:
    full_data = json.load(f)

location_types = full_data["data"]

pprint(location_types)
# Out:
# [{'category': 'S',
#   'code': 'AIRQ',
#   'description': 'abandoned airfield',
#   'name': 'abandoned airfield',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CMPQ',
#   'description': 'abandoned camp',
#   'name': 'abandoned camp',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNLQ',
#   'description': 'abandoned canal',
#   'name': 'abandoned canal',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MFGQ',
#   'description': 'abandoned factory',
#   'name': 'abandoned factory',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FRMQ',
#   'description': 'abandoned farm',
#   'name': 'abandoned farm',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNQ',
#   'description': 'abandoned mine',
#   'name': 'abandoned mine',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MSSNQ',
#   'description': 'abandoned mission',
#   'name': 'abandoned mission',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'OILQ',
#   'description': 'abandoned oil well',
#   'name': 'abandoned oil well',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PPQ',
#   'description': 'abandoned police post',
#   'name': 'abandoned police post',
#   'status': 'active'},
#  {'category': 'P',
#   'code': 'PPLQ',
#   'description': 'abandoned populated place',
#   'name': 'abandoned populated place',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PRNQ',
#   'description': 'abandoned prison',
#   'name': 'abandoned prison',
#   'status': 'active'},
#  {'category': 'R',
#   'code': 'RRQ',
#   'description': 'abandoned railroad',
#   'name': 'abandoned railroad',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'RSTNQ',
#   'description': 'abandoned railroad station',
#   'name': 'abandoned railroad station',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'RSTPQ',
#   'description': 'abandoned railroad stop',
#   'name': 'abandoned railroad stop',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'STMQ',
#   'description': 'a former stream or distributary no longer carrying flowing '
#                  'water, but still evident due to lakes, wetland, topographic '
#                  'or vegetation patterns',
#   'name': 'abandoned watercourse',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WLLQ',
#   'description': 'abandoned well',
#   'name': 'abandoned well',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADMD',
#   'description': 'an administrative division of a political entity, '
#                  'undifferentiated as to administrative level',
#   'name': 'administrative division',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ADMF',
#   'description': 'a government building',
#   'name': 'administrative facility',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'AGRC',
#   'description': 'a tract of land set aside for agricultural settlement',
#   'name': 'agricultural colony',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AGRF',
#   'description': 'a building and/or tract of land used for improving '
#                  'agriculture',
#   'name': 'agricultural facility',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RESA',
#   'description': 'a tract of land reserved for agricultural reclamation and/or '
#                  'development',
#   'name': 'agricultural reserve',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'SCHA',
#   'description': 'a school with a curriculum focused on agriculture',
#   'name': 'agricultural school',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AIRB',
#   'description': 'an area used to store supplies, provide barracks for air '
#                  'force personnel, hangars and runways for aircraft, and from '
#                  'which operations are initiated',
#   'name': 'airbase',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AIRF',
#   'description': 'a place on land where aircraft land and take off; no '
#                  'facilities provided for the commercial handling of '
#                  'passengers and cargo',
#   'name': 'airfield',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AIRP',
#   'description': 'a place where aircraft regularly land and take off, with '
#                  'runways, navigational aids, and major facilities for the '
#                  'commercial handling of passengers and cargo',
#   'name': 'airport',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AMTH',
#   'description': 'an oval or circular structure with rising tiers of seats '
#                  'about a stage or open space',
#   'name': 'amphitheater',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'STMA',
#   'description': 'a diverging branch flowing out of a main stream and '
#                  'rejoining it downstream',
#   'name': 'anabranch',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'ANCH',
#   'description': 'an area where vessels may anchor',
#   'name': 'anchorage',
#   'status': 'active'},
#  {'category': 'R',
#   'code': 'RDA',
#   'description': 'the remains of a road used by ancient cultures',
#   'name': 'ancient road',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ANS',
#   'description': 'a place where archeological remains, old structures, or '
#                  'cultural artifacts are located',
#   'name': 'ancient site',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WALLA',
#   'description': 'the remains of a linear defensive stone structure',
#   'name': 'ancient wall',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BLDA',
#   'description': 'a building containing several individual apartments',
#   'name': 'apartment building',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AQC',
#   'description': 'facility or area for the cultivation of aquatic animals and '
#                  'plants, especially fish, shellfish, and seaweed, in natural '
#                  'or controlled marine or freshwater environments; underwater '
#                  'agriculture',
#   'name': 'aquaculture facility',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNLA',
#   'description': 'a conduit used to carry water',
#   'name': 'aqueduct',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ARCH',
#   'description': 'a natural or man-made structure in the form of an arch',
#   'name': 'arch',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'LAND',
#   'description': 'a tract of land in the Arctic',
#   'name': 'Arctic land',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'AREA',
#   'description': 'a tract of land without homogeneous character or boundaries',
#   'name': 'area',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'ISLF',
#   'description': 'an island created by landfill or diking and filling in a '
#                  'wetland, bay, or lagoon',
#   'name': 'artificial island',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RNGA',
#   'description': 'a tract of land used for artillery firing practice',
#   'name': 'artillery range',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'ASPH',
#   'description': 'a small basin containing naturally occurring asphalt',
#   'name': 'asphalt lake',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ASTR',
#   'description': 'a point on the earth whose position has been determined by '
#                  'observations of celestial bodies',
#   'name': 'astronomical station',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ASYL',
#   'description': 'a facility where the insane are cared for and protected',
#   'name': 'asylum',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ATHF',
#   'description': 'a tract of land used for playing team sports, and athletic '
#                  'track and field events',
#   'name': 'athletic field',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'ATOL',
#   'description': 'a ring-shaped coral reef which has closely spaced islands on '
#                  'it encircling a lagoon',
#   'name': 'atoll(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CTRA',
#   'description': 'a facility where atomic research is carried out',
#   'name': 'atomic center',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BDLD',
#   'description': 'an area characterized by a maze of very closely spaced, '
#                  'deep, narrow, steep-sided ravines, and sharp crests and '
#                  'pinnacles',
#   'name': 'badlands',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BSTN',
#   'description': 'a facility for baling agricultural products',
#   'name': 'baling station',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ESTB',
#   'description': 'an estate that specializes in the growing of bananas',
#   'name': 'banana plantation',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BAN',
#   'description': 'an establishment for the custody, loan, exchange or issue of '
#                  'money, for the extension of credit, and for facilitating the '
#                  'transmission of funds',
#   'name': 'bank',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'BNK',
#   'description': 'an elevation, typically located on a shelf, over which the '
#                  'depth of water is relatively shallow but sufficient for most '
#                  'surface navigation',
#   'name': 'bank(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BAR',
#   'description': 'a shallow ridge or mound of coarse unconsolidated material '
#                  'in a stream channel, at the mouth of a stream, estuary, or '
#                  'lagoon and in the wave-break zone along coasts',
#   'name': 'bar',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BRKS',
#   'description': 'a building for lodging military personnel',
#   'name': 'barracks',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'BTL',
#   'description': 'a site of a land battle of historical importance',
#   'name': 'battlefield',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'BAY',
#   'description': 'a coastal indentation between two capes or headlands, larger '
#                  'than a cove but smaller than a gulf',
#   'name': 'bay',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'BAYS',
#   'description': 'coastal indentations between two capes or headlands, larger '
#                  'than a cove but smaller than a gulf',
#   'name': 'bays',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BCH',
#   'description': 'a shore zone of coarse unconsolidated sediment that extends '
#                  'from the low-water line to the highest reach of storm waves',
#   'name': 'beach',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'RDGB',
#   'description': 'a ridge of sand just inland and parallel to the beach, '
#                  'usually in series',
#   'name': 'beach ridge',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BCHS',
#   'description': 'a shore zone of coarse unconsolidated sediment that extends '
#                  'from the low-water line to the highest reach of storm waves',
#   'name': 'beaches',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BCN',
#   'description': 'a fixed artificial navigation mark',
#   'name': 'beacon',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BNCH',
#   'description': 'a long, narrow bedrock platform bounded by steeper slopes '
#                  'above and below, usually overlooking a waterbody',
#   'name': 'bench',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'BGHT',
#   'description': 'an open body of water forming a slight recession in a '
#                  'coastline',
#   'name': 'bight(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BLHL',
#   'description': 'a hole in coastal rock through which sea water is forced by '
#                  'a rising tide or waves and spurted through an outlet into '
#                  'the air',
#   'name': 'blowhole(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BLOW',
#   'description': 'a small depression in sandy terrain, caused by wind erosion',
#   'name': 'blowout(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BTYD',
#   'description': 'a waterside facility for servicing, repairing, and building '
#                  'small vessels',
#   'name': 'boatyard',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'BOG',
#   'description': 'a wetland characterized by peat forming sphagnum moss, '
#                  'sedge, and other acid-water plants',
#   'name': 'bog(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PSTB',
#   'description': 'a post or station at an international boundary for the '
#                  'regulation of movement of people and goods',
#   'name': 'border post',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BLDR',
#   'description': 'a high altitude or high latitude bare, flat area covered '
#                  'with large angular rocks',
#   'name': 'boulder field',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BP',
#   'description': 'a fixture marking a point along a boundary',
#   'name': 'boundary marker',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BRKW',
#   'description': 'a structure erected to break the force of waves at the '
#                  'entrance to a harbor or port',
#   'name': 'breakwater',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MFGB',
#   'description': 'one or more buildings where beer is brewed',
#   'name': 'brewery',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BDG',
#   'description': 'a structure erected across an obstacle such as a stream, '
#                  'road, etc., in order to carry roads, railroads, and '
#                  'pedestrians across',
#   'name': 'bridge',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ZNB',
#   'description': 'a zone recognized as a buffer between two nations in which '
#                  'military presence is minimal or absent',
#   'name': 'buffer zone',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BLDG',
#   'description': 'a structure built for permanent use, as a house, factory, '
#                  'etc.',
#   'name': 'building(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'BUR',
#   'description': 'a cave used for human burials',
#   'name': 'burial cave(s)',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'BUSH',
#   'description': 'a small clump of conspicuous bushes in an otherwise bare '
#                  'area',
#   'name': 'bush(es)',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'CTRB',
#   'description': 'a place where a number of businesses are located',
#   'name': 'business center',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'BUTE',
#   'description': 'a small, isolated, usually flat-topped hill with steep sides',
#   'name': 'butte(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CARN',
#   'description': 'a heap of stones erected as a landmark or for other purposes',
#   'name': 'cairn',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CLDA',
#   'description': 'a depression measuring kilometers across formed by the '
#                  'collapse of a volcanic mountain',
#   'name': 'caldera',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CMP',
#   'description': 'a site occupied by tents, huts, or other shelters for '
#                  'temporary use',
#   'name': 'camp(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNL',
#   'description': 'an artificial watercourse',
#   'name': 'canal',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNLB',
#   'description': 'a conspicuously curved or bent section of a canal',
#   'name': 'canal bend',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'TNLC',
#   'description': 'a tunnel through which a canal passes',
#   'name': 'canal tunnel',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'STMC',
#   'description': 'a stream that has been substantially ditched, diked, or '
#                  'straightened',
#   'name': 'canalized stream',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MFGC',
#   'description': 'a building where food items are canned',
#   'name': 'cannery',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CNYN',
#   'description': 'a deep, narrow valley with steep sides cutting into a '
#                  'plateau or mountainous area',
#   'name': 'canyon',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CAPE',
#   'description': 'a land area, more prominent than a point, projecting into '
#                  'the sea and marking a notable change in coastal direction',
#   'name': 'cape',
#   'status': 'active'},
#  {'category': 'P',
#   'code': 'PPLC',
#   'description': 'capital of a political entity',
#   'name': 'capital of a political entity',
#   'status': 'active'},
#  {'category': 'R',
#   'code': 'RTE',
#   'description': 'the route taken by caravans',
#   'name': 'caravan route',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CSNO',
#   'description': 'a building used for entertainment, especially gambling',
#   'name': 'casino',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CSTL',
#   'description': 'a large fortified building or set of buildings',
#   'name': 'castle',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'TNKD',
#   'description': 'a small artificial pond used for immersing cattle in '
#                  'chemically treated water for disease control',
#   'name': 'cattle dipping tank',
#   'status': 'active'},
#  {'category': 'R',
#   'code': 'CSWY',
#   'description': 'a raised roadway across wet ground or shallow water',
#   'name': 'causeway',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CAVE',
#   'description': 'an underground passageway or chamber, or cavity on the side '
#                  'of a cliff',
#   'name': 'cave(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CMTY',
#   'description': 'a burial place or ground',
#   'name': 'cemetery',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CHN',
#   'description': 'the deepest part of a stream, bay, lagoon, or strait, '
#                  'through which the main current flows',
#   'name': 'channel',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNCR',
#   'description': 'a mine where chrome ore is extracted',
#   'name': 'chrome mine(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CH',
#   'description': 'a building for public Christian worship',
#   'name': 'church',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CRQ',
#   'description': 'a bowl-like hollow partially surrounded by cliffs or steep '
#                  'slopes at the head of a glaciated valley',
#   'name': 'cirque',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CRQS',
#   'description': 'bowl-like hollows partially surrounded by cliffs or steep '
#                  'slopes at the head of a glaciated valley',
#   'name': 'cirques',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'CLG',
#   'description': 'an area in a forest with trees removed',
#   'name': 'clearing',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CFT',
#   'description': 'a deep narrow slot, notch, or groove in a coastal cliff',
#   'name': 'cleft(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CLF',
#   'description': 'a high, steep to perpendicular slope overlooking a waterbody '
#                  'or lower area',
#   'name': 'cliff(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSPC',
#   'description': 'a medical facility associated with a hospital for '
#                  'outpatients',
#   'name': 'clinic',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNC',
#   'description': 'a mine where coal is extracted',
#   'name': 'coal mine(s)',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'COLF',
#   'description': 'a region in which coal deposits of possible economic value '
#                  'occur',
#   'name': 'coalfield',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'CST',
#   'description': 'a zone of variable width straddling the shoreline',
#   'name': 'coast',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'STNC',
#   'description': 'a facility from which the coast is guarded by armed vessels',
#   'name': 'coast guard station',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'GRVC',
#   'description': 'a planting of coconut trees',
#   'name': 'coconut grove',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'SCHC',
#   'description': 'the grounds and buildings of an institution of higher '
#                  'learning',
#   'name': 'college',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'CMN',
#   'description': 'a park or pasture for community use',
#   'name': 'common',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'COMC',
#   'description': 'a facility, including buildings, antennae, towers and '
#                  'electronic equipment for receiving and transmitting '
#                  'information',
#   'name': 'communication center',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CTRCM',
#   'description': 'a facility for community recreation and other activities',
#   'name': 'community center',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'CNS',
#   'description': 'a lease of land by a government for economic development, '
#                  'e.g., mining, forestry',
#   'name': 'concession area',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CONE',
#   'description': 'a conical landform composed of mud or volcanic material',
#   'name': 'cone(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNFL',
#   'description': 'a place where two or more streams or intermittent streams '
#                  'flow together',
#   'name': 'confluence',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'CRSU',
#   'description': 'a gentle slope rising from oceanic depths towards the foot '
#                  'of a continental slope',
#   'name': 'continental rise',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CVNT',
#   'description': 'a building where a community of nuns lives in seclusion',
#   'name': 'convent',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNCU',
#   'description': 'a mine where copper ore is extracted',
#   'name': 'copper mine(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MFGCU',
#   'description': 'a facility for processing copper ore',
#   'name': 'copper works',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'RFC',
#   'description': 'a surface-navigation hazard composed of coral',
#   'name': 'coral reef(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CRRL',
#   'description': 'a pen or enclosure for confining or capturing animals',
#   'name': 'corral(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CRDR',
#   'description': 'a strip or area of land having significance as an access way',
#   'name': 'corridor',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ESTC',
#   'description': 'an estate specializing in the cultivation of cotton',
#   'name': 'cotton plantation',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSEC',
#   'description': 'a large house, mansion, or chateau, on a large estate',
#   'name': 'country house',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CTHSE',
#   'description': 'a building in which courts of law are held',
#   'name': 'courthouse',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'COVE',
#   'description': 'a small coastal indentation, smaller than a bay',
#   'name': 'cove(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'LKC',
#   'description': 'a lake in a crater or caldera',
#   'name': 'crater lake',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'LKSC',
#   'description': 'lakes in a crater or caldera',
#   'name': 'crater lakes',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CRTR',
#   'description': 'a generally circular saucer or bowl-shaped depression caused '
#                  'by volcanic or meteorite explosive action',
#   'name': 'crater(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'CUET',
#   'description': 'an asymmetric ridge formed on tilted strata',
#   'name': 'cuesta(s)',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'CULT',
#   'description': 'an area under cultivation',
#   'name': 'cultivated area',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CRNT',
#   'description': 'a horizontal flow of water in a given direction with uniform '
#                  'velocity',
#   'name': 'current',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CSTM',
#   'description': 'a building in a port where customs and duties are paid, and '
#                  'where vessels are entered and cleared',
#   'name': 'customs house',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PSTC',
#   'description': 'a building at an international boundary where customs and '
#                  'duties are paid on goods',
#   'name': 'customs post',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CUTF',
#   'description': 'a channel formed as a result of a stream cutting through a '
#                  'meander neck',
#   'name': 'cutoff',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DARY',
#   'description': 'a facility for the processing, sale and distribution of milk '
#                  'or milk products',
#   'name': 'dairy',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DAM',
#   'description': 'a barrier constructed across a stream to impound water',
#   'name': 'dam',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'DEPU',
#   'description': 'a localized deep area within the confines of a larger '
#                  'feature, such as a trough, basin or trench',
#   'name': 'deep',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'DLTA',
#   'description': 'a flat plain formed by alluvial deposits at the mouth of a '
#                  'stream',
#   'name': 'delta',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'PCLD',
#   'description': 'dependent political entity',
#   'name': 'dependent political entity',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'DPR',
#   'description': 'a low area surrounded by higher land and usually '
#                  'characterized by interior drainage',
#   'name': 'depression(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'DSRT',
#   'description': 'a large area with little or no vegetation due to extreme '
#                  'environmental conditions',
#   'name': 'desert',
#   'status': 'active'},
#  {'category': 'P',
#   'code': 'PPLW',
#   'description': 'a village, town or city destroyed by a natural disaster, or '
#                  'by war',
#   'name': 'destroyed populated place',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNDT',
#   'description': 'a place where diatomaceous earth is extracted',
#   'name': 'diatomite mine(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DIKE',
#   'description': 'an earth or stone embankment usually constructed for flood '
#                  'or stream control',
#   'name': 'dike',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DIP',
#   'description': 'office, residence, or facility of a foreign government, '
#                  'which may include an embassy, consulate, chancery, office of '
#                  'charge d’affaires, or other diplomatic, economic, military, '
#                  'or cultural mission',
#   'name': 'diplomatic facility',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSPD',
#   'description': 'a building where medical or dental aid is dispensed',
#   'name': 'dispensary',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'STMD',
#   'description': 'a branch which flows away from the main stream, as in a '
#                  'delta or irrigation canal',
#   'name': 'distributary(-ies)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DTCH',
#   'description': 'a small artificial watercourse dug for draining or '
#                  'irrigating the land',
#   'name': 'ditch',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DTCHM',
#   'description': 'an area where a drainage ditch enters a lagoon, lake or bay',
#   'name': 'ditch mouth(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'DVD',
#   'description': 'a line separating adjacent drainage basins',
#   'name': 'divide',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DCK',
#   'description': 'a waterway between two piers, or cut into the land for the '
#                  'berthing of ships',
#   'name': 'dock(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DCKB',
#   'description': 'a part of a harbor where ships dock',
#   'name': 'docking basin',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DCKY',
#   'description': 'a facility for servicing, building, or repairing ships',
#   'name': 'dockyard',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'BSND',
#   'description': 'an area drained by a stream',
#   'name': 'drainage basin',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CNLD',
#   'description': 'an artificial waterway carrying water away from a wetland or '
#                  'from drainage ditches',
#   'name': 'drainage canal',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DTCHD',
#   'description': 'a ditch which serves to drain the land',
#   'name': 'drainage ditch',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DCKD',
#   'description': 'a dock providing support for a vessel, and means for '
#                  'removing the water so that the bottom of the vessel can be '
#                  'exposed',
#   'name': 'dry dock',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'SBED',
#   'description': 'a channel formerly containing the water of a stream',
#   'name': 'dry stream bed',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'DUNE',
#   'description': 'a wave form, ridge or star shape feature composed of sand',
#   'name': 'dune(s)',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RGNE',
#   'description': 'a region of a country established for economic development '
#                  'or for statistical purposes',
#   'name': 'economic region',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'SCRP',
#   'description': 'a long line of cliffs or steep slopes separating level '
#                  'surfaces above and below',
#   'name': 'escarpment',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'EST',
#   'description': 'a large commercialized agricultural landholding with '
#                  'associated buildings and other facilities',
#   'name': 'estate(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'ESTY',
#   'description': 'a funnel-shaped stream mouth or embayment where fresh water '
#                  'mixes with sea water under tidal influences',
#   'name': 'estuary',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'STNE',
#   'description': 'a facility for carrying out experiments',
#   'name': 'experiment station',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FCL',
#   'description': 'a building or buildings housing a center, institute, '
#                  'foundation, hospital, prison, mission, courthouse, etc.',
#   'name': 'facility',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'CTRF',
#   'description': 'a place where more than one facility is situated',
#   'name': 'facility center',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MFG',
#   'description': 'one or more buildings where goods are manufactured, '
#                  'processed or fabricated',
#   'name': 'factory',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'FAN',
#   'description': 'a fan-shaped wedge of coarse alluvium with apex merging with '
#                  'a mountain stream bed and the fan spreading out at a low '
#                  'angle slope onto an adjacent plain',
#   'name': 'fan(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FRM',
#   'description': 'a tract of land with associated buildings devoted to '
#                  'agriculture',
#   'name': 'farm',
#   'status': 'active'},
#  {'category': 'P',
#   'code': 'PPLF',
#   'description': 'a populated place where the population is largely engaged in '
#                  'agricultural activities',
#   'name': 'farm village',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FRMS',
#   'description': 'tracts of land with associated buildings devoted to '
#                  'agriculture',
#   'name': 'farms',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FRMT',
#   'description': 'the buildings and adjacent service areas of a farm',
#   'name': 'farmstead',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FY',
#   'description': 'a boat or other floating conveyance and terminal facilities '
#                  'regularly used to transport people and vehicles across a '
#                  'waterbody',
#   'name': 'ferry',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FYT',
#   'description': 'a place where ferries pick-up and discharge passengers, '
#                  'vehicles and or cargo',
#   'name': 'ferry terminal',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'FLD',
#   'description': 'an open as opposed to wooded area',
#   'name': 'field(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FIRE',
#   'description': 'building housing firefighters and/or fire fighting equipment',
#   'name': 'fire station',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM1',
#   'description': 'a primary administrative division of a country, such as a '
#                  'state in the United States',
#   'name': 'first-order administrative division',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'FISH',
#   'description': 'a fishing ground, bank or area where fishermen go to catch '
#                  'fish',
#   'name': 'fishing area',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'PNDSF',
#   'description': 'ponds or enclosures in which fish are kept or raised',
#   'name': 'fishponds',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'FSR',
#   'description': 'a crack associated with volcanism',
#   'name': 'fissure',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'FJD',
#   'description': 'a long, narrow, steep-walled, deep-water arm of the sea at '
#                  'high latitudes, usually along mountainous coasts',
#   'name': 'fjord',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'FJDS',
#   'description': 'long, narrow, steep-walled, deep-water arms of the sea at '
#                  'high latitudes, usually along mountainous coasts',
#   'name': 'fjords',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'FORD',
#   'description': 'a shallow part of a stream which can be crossed on foot or '
#                  'by land vehicle',
#   'name': 'ford',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RESF',
#   'description': 'a forested area set aside for preservation or controlled use',
#   'name': 'forest reserve',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'STNF',
#   'description': 'a collection of buildings and facilities for carrying out '
#                  'forest management',
#   'name': 'forest station',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'FRST',
#   'description': 'an area dominated by tree vegetation',
#   'name': 'forest(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'INLTQ',
#   'description': 'an inlet which has been filled in, or blocked by deposits',
#   'name': 'former inlet',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MLSGQ',
#   'description': 'a sugar mill no longer used as a sugar mill',
#   'name': 'former sugar mill',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FT',
#   'description': 'a defensive structure or earthworks',
#   'name': 'fort',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'FRSTF',
#   'description': 'a forest fossilized by geologic processes and now exposed at '
#                  "the earth's surface",
#   'name': 'fossilized forest',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'FNDY',
#   'description': 'a building or works where metal casting is carried out',
#   'name': 'foundry',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM4',
#   'description': 'a subdivision of a third-order administrative division',
#   'name': 'fourth-order administrative division',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ZNF',
#   'description': 'an area, usually a section of a port, where goods may be '
#                  'received and shipped free of customs duty and of most '
#                  'customs regulations',
#   'name': 'free trade zone',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'PCLF',
#   'description': 'freely associated state',
#   'name': 'freely associated state',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'DPOF',
#   'description': 'an area where fuel is stored',
#   'name': 'fuel depot',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'GAP',
#   'description': 'a low place in a ridge, not used for transportation',
#   'name': 'gap',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GDN',
#   'description': 'an enclosure for displaying selected plant or animal life',
#   'name': 'garden(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GOSP',
#   'description': 'a facility for separating gas from oil',
#   'name': 'gas-oil separator plant',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'GASF',
#   'description': 'an area containing a subterranean store of natural gas of '
#                  'economic value',
#   'name': 'gasfield',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GATE',
#   'description': 'a controlled access entrance or exit',
#   'name': 'gate',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'GYSR',
#   'description': 'a type of hot spring with intermittent eruptions of jets of '
#                  'hot water and steam',
#   'name': 'geyser',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GHAT',
#   'description': 'a set of steps leading to a river, which are of religious '
#                  'significance, and at their base is usually a platform for '
#                  'bathing',
#   'name': 'ghāt',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'GLCR',
#   'description': 'a mass of ice, usually at high latitudes or high elevations, '
#                  'with sufficient thickness to flow away from the source area '
#                  'in lobes, tongues, or masses',
#   'name': 'glacier(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MNAU',
#   'description': 'a mine where gold ore, or alluvial gold is extracted',
#   'name': 'gold mine(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'RECG',
#   'description': 'a recreation field where golf is played',
#   'name': 'golf course',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'GRGE',
#   'description': 'a short, narrow, steep-sided section of a stream valley',
#   'name': 'gorge(s)',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'GRSLD',
#   'description': 'an area dominated by grass vegetation',
#   'name': 'grassland',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GRVE',
#   'description': 'a burial site',
#   'name': 'grave',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'GVL',
#   'description': 'an area covered with gravel',
#   'name': 'gravel area',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'GRAZ',
#   'description': 'an area of grasses and shrubs used for grazing',
#   'name': 'grazing area',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'GHSE',
#   'description': 'a house used to provide lodging for paying guests',
#   'name': 'guest house',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'GULF',
#   'description': 'a large recess in the coastline, larger than a bay',
#   'name': 'gulf',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HLT',
#   'description': 'a place where caravans stop for rest',
#   'name': 'halting place',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'HMCK',
#   'description': 'a patch of ground, distinct from and slightly above the '
#                  'surrounding plain or wetland. Often occurs in groups',
#   'name': 'hammock(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AIRG',
#   'description': 'a covered and usually enclosed area for housing and '
#                  'repairing aircraft',
#   'name': 'hangar',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'VALG',
#   'description': 'a valley the floor of which is notably higher than the '
#                  'valley or shore to which it leads; most common in areas that '
#                  'have been glaciated',
#   'name': 'hanging valley',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'HBR',
#   'description': 'a haven or space of deep water so sheltered by the adjacent '
#                  'land as to afford a safe anchorage for ships',
#   'name': 'harbor(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'HDLD',
#   'description': 'a high projection of land extending into a large body of '
#                  'water beyond the line of the coast',
#   'name': 'headland',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'STMH',
#   'description': 'the source and upper part of a stream, including the upper '
#                  'drainage basin',
#   'name': 'headwaters',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'HTH',
#   'description': 'an upland moor or sandy area dominated by low shrubby '
#                  'vegetation including heather',
#   'name': 'heath',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'AIRH',
#   'description': 'a place where helicopters land and take off',
#   'name': 'heliport',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HERM',
#   'description': 'a secluded residence, usually for religious sects',
#   'name': 'hermitage',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'HLL',
#   'description': 'a rounded elevation of limited extent rising above the '
#                  'surrounding land with local relief of less than 300m',
#   'name': 'hill',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'HLLS',
#   'description': 'rounded elevations of limited extent rising above the '
#                  'surrounding land with local relief of less than 300m',
#   'name': 'hills',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADMDH',
#   'description': 'a former administrative division of a political entity, '
#                  'undifferentiated as to administrative level',
#   'name': 'historical administrative division',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM1H',
#   'description': 'a former first-order administrative division',
#   'name': 'historical first-order administrative division',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM4H',
#   'description': 'a former fourth-order administrative division',
#   'name': 'historical fourth-order administrative division',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'PCLH',
#   'description': 'a former political entity',
#   'name': 'historical political entity',
#   'status': 'active'},
#  {'category': 'P',
#   'code': 'PPLH',
#   'description': 'a populated place that no longer exists',
#   'name': 'historical populated place',
#   'status': 'active'},
#  {'category': 'R',
#   'code': 'RRH',
#   'description': 'a former permanent twin steel-rail track on which freight '
#                  'and passenger cars move long distances',
#   'name': 'historical railroad',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'RSTNH',
#   'description': 'a former facility comprising ticket office, platforms, etc. '
#                  'for loading and unloading train passengers and freight',
#   'name': 'historical railroad station',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RGNH',
#   'description': 'a former area distinguished by one or more observable '
#                  'physical or cultural characteristics',
#   'name': 'historical region',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM2H',
#   'description': 'a former second-order administrative division',
#   'name': 'historical second-order administrative division',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSTS',
#   'description': 'a place of historical importance',
#   'name': 'historical site',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ADM3H',
#   'description': 'a former third-order administrative division',
#   'name': 'historical third-order administrative division',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'UFHU',
#   'description': 'an undersea feature whose existence has been subsequently '
#                  'disproved',
#   'name': 'historical undersea feature',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HMSD',
#   'description': "a residence, owner's or manager's, on a sheep or cattle "
#                  'station, woolshed, outcamp, or Aboriginal outstation, '
#                  'specific to Australia and New Zealand',
#   'name': 'homestead',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSP',
#   'description': 'a building in which sick or injured, especially those '
#                  'confined to bed, are medically treated',
#   'name': 'hospital',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'SPNT',
#   'description': 'a place where hot ground water flows naturally out of the '
#                  'ground',
#   'name': 'hot spring(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HTL',
#   'description': 'a building providing lodging and/or meals for the public',
#   'name': 'hotel',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HSE',
#   'description': 'a building used as a human habitation',
#   'name': 'house(s)',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'DEVH',
#   'description': 'a tract of land on which many houses of similar design are '
#                  'built according to a development plan',
#   'name': 'housing development',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RESH',
#   'description': 'a tract of land used primarily for hunting',
#   'name': 'hunting reserve',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HUT',
#   'description': 'a small primitive house',
#   'name': 'hut',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'HUTS',
#   'description': 'small primitive houses',
#   'name': 'huts',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PSH',
#   'description': 'a building where electricity is generated from water power',
#   'name': 'hydroelectric power station',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'CAPG',
#   'description': 'a dome-shaped mass of glacial ice covering an area of '
#                  'mountain summits or other high lands; smaller than an ice '
#                  'sheet',
#   'name': 'icecap',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DPRG',
#   'description': 'a comparatively depressed area on an icecap',
#   'name': 'icecap depression',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'DOMG',
#   'description': 'a comparatively elevated area on an icecap',
#   'name': 'icecap dome',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'RDGG',
#   'description': 'a linear elevation on an icecap',
#   'name': 'icecap ridge',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'PCLI',
#   'description': 'independent political entity',
#   'name': 'independent political entity',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'INDS',
#   'description': 'an area characterized by industrial activity',
#   'name': 'industrial area',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'INLT',
#   'description': 'a narrow waterway extending into the land, or connecting a '
#                  'bay or lagoon with a larger body of water',
#   'name': 'inlet',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'STNI',
#   'description': 'a station at which vehicles, goods, and people are inspected',
#   'name': 'inspection station',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'TRGD',
#   'description': 'a long wind-swept trough between parallel longitudinal dunes',
#   'name': 'interdune trough(s)',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'INTF',
#   'description': 'a relatively undissected upland between adjacent stream '
#                  'valleys',
#   'name': 'interfluve',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'LKI',
#   'description': 'intermittent lake',
#   'name': 'intermittent lake',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'LKSI',
#   'description': 'intermittent lakes',
#   'name': 'intermittent lakes',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'LKOI',
#   'description': 'intermittent oxbow lake',
#   'name': 'intermittent oxbow lake',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'PNDI',
#   'description': 'intermittent pond',
#   'name': 'intermittent pond',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'PNDSI',
#   'description': 'intermittent ponds',
#   'name': 'intermittent ponds',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'POOLI',
#   'description': 'intermittent pool',
#   'name': 'intermittent pool',
#   'status': 'active'},
#  {'category': 'H',
# ...
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'FURU',
#   'description': 'a closed, linear, narrow, shallow depression',
#   'name': 'undersea furrow',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'GAPU',
#   'description': 'a narrow break in a ridge or rise',
#   'name': 'undersea gap',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'GLYU',
#   'description': 'a small valley-like feature',
#   'name': 'undersea gully',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'HLLU',
#   'description': 'an elevation rising generally less than 500 meters',
#   'name': 'undersea hill',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'HLSU',
#   'description': 'elevations rising generally less than 500 meters',
#   'name': 'undersea hills',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'HOLU',
#   'description': 'a small depression of the sea floor',
#   'name': 'undersea hole',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'KNLU',
#   'description': 'an elevation rising generally more than 500 meters and less '
#                  'than 1,000 meters and of limited extent across the summit',
#   'name': 'undersea knoll',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'KNSU',
#   'description': 'elevations rising generally more than 500 meters and less '
#                  'than 1,000 meters and of limited extent across the summits',
#   'name': 'undersea knolls',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'LDGU',
#   'description': 'a rocky projection or outcrop, commonly linear and near '
#                  'shore',
#   'name': 'undersea ledge',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'LEVU',
#   'description': 'an embankment bordering a canyon, valley, or seachannel',
#   'name': 'undersea levee',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MDVU',
#   'description': 'the axial depression of the mid-oceanic ridge system',
#   'name': 'undersea median valley',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MESU',
#   'description': 'an isolated, extensive, flat-topped elevation on the shelf, '
#                  'with relatively steep sides',
#   'name': 'undersea mesa',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MOTU',
#   'description': 'an annular depression that may not be continuous, located at '
#                  'the base of many seamounts, islands, and other isolated '
#                  'elevations',
#   'name': 'undersea moat',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MNDU',
#   'description': 'a low, isolated, rounded hill',
#   'name': 'undersea mound',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MTU',
#   'description': 'a well-delineated subdivision of a large and complex '
#                  'positive feature',
#   'name': 'undersea mountain',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'MTSU',
#   'description': 'well-delineated subdivisions of a large and complex positive '
#                  'feature',
#   'name': 'undersea mountains',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PKU',
#   'description': 'a prominent elevation, part of a larger feature, either '
#                  'pointed or of very limited extent across the summit',
#   'name': 'undersea peak',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PKSU',
#   'description': 'prominent elevations, part of a larger feature, either '
#                  'pointed or of very limited extent across the summit',
#   'name': 'undersea peaks',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PNLU',
#   'description': 'a high tower or spire-shaped pillar of rock or coral, alone '
#                  'or cresting a summit',
#   'name': 'undersea pinnacle',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PLNU',
#   'description': 'a flat, gently sloping or nearly level region',
#   'name': 'undersea plain',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PLTU',
#   'description': 'a comparatively flat-topped feature of considerable extent, '
#                  'dropping off abruptly on one or more sides',
#   'name': 'undersea plateau',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PLFU',
#   'description': 'a flat or gently sloping underwater surface extending '
#                  'seaward from the shore',
#   'name': 'undersea platform',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'PRVU',
#   'description': 'a region identifiable by a group of similar physiographic '
#                  'features whose characteristics are markedly in contrast with '
#                  'surrounding areas',
#   'name': 'undersea province',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RMPU',
#   'description': 'a gentle slope connecting areas of different elevations',
#   'name': 'undersea ramp',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RNGU',
#   'description': 'a series of associated ridges or seamounts',
#   'name': 'undersea range',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RAVU',
#   'description': 'a small canyon',
#   'name': 'undersea ravine',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RFU',
#   'description': 'a surface-navigation hazard composed of consolidated '
#                  'material',
#   'name': 'undersea reef',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RFSU',
#   'description': 'surface-navigation hazards composed of consolidated material',
#   'name': 'undersea reefs',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RDGU',
#   'description': 'a long narrow elevation with steep sides',
#   'name': 'undersea ridge',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RDSU',
#   'description': 'long narrow elevations with steep sides',
#   'name': 'undersea ridges',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'RISU',
#   'description': 'a broad elevation that rises gently, and generally smoothly, '
#                  'from the sea floor',
#   'name': 'undersea rise',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SDLU',
#   'description': 'a low part, resembling in shape a saddle, in a ridge or '
#                  'between contiguous seamounts',
#   'name': 'undersea saddle',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SHFU',
#   'description': 'a zone adjacent to a continent (or around an island) that '
#                  'extends from the low water line to a depth at which there is '
#                  'usually a marked increase of slope towards oceanic depths',
#   'name': 'undersea shelf',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'EDGU',
#   'description': 'a line along which there is a marked increase of slope at '
#                  'the outer margin of a continental shelf or island shelf',
#   'name': 'undersea shelf edge',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SHVU',
#   'description': 'a valley on the shelf, generally the shoreward extension of '
#                  'a canyon',
#   'name': 'undersea shelf valley',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SHLU',
#   'description': 'a surface-navigation hazard composed of unconsolidated '
#                  'material',
#   'name': 'undersea shoal',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SHSU',
#   'description': 'hazards to surface navigation composed of unconsolidated '
#                  'material',
#   'name': 'undersea shoals',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SILU',
#   'description': 'the low part of an underwater gap or saddle separating '
#                  'basins, including a similar feature at the mouth of a fjord',
#   'name': 'undersea sill',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SLPU',
#   'description': 'the slope seaward from the shelf edge to the beginning of a '
#                  'continental rise or the point where there is a general '
#                  'reduction in slope',
#   'name': 'undersea slope',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'SPRU',
#   'description': 'a subordinate elevation, ridge, or rise projecting outward '
#                  'from a larger feature',
#   'name': 'undersea spur',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'TERU',
#   'description': 'a relatively flat horizontal or gently inclined surface, '
#                  'sometimes long and narrow, which is bounded by a steeper '
#                  'ascending slope on one side and by a steep descending slope '
#                  'on the opposite side',
#   'name': 'undersea terrace',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'TNGU',
#   'description': 'an elongate (tongue-like) extension of a flat sea floor into '
#                  'an adjacent higher feature',
#   'name': 'undersea tongue',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'TRNU',
#   'description': 'a long, narrow, characteristically very deep and '
#                  'asymmetrical depression of the sea floor, with relatively '
#                  'steep sides',
#   'name': 'undersea trench',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'TRGU',
#   'description': 'a long depression of the sea floor characteristically flat '
#                  'bottomed and steep sided, and normally shallower than a '
#                  'trench',
#   'name': 'undersea trough',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'VALU',
#   'description': 'a relatively shallow, wide depression, the bottom of which '
#                  'usually has a continuous gradient',
#   'name': 'undersea valley',
#   'status': 'active'},
#  {'category': 'U',
#   'code': 'VLSU',
#   'description': 'a relatively shallow, wide depression, the bottom of which '
#                  'usually has a continuous gradient',
#   'name': 'undersea valleys',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'USGE',
#   'description': 'a facility operated by the United States Government in '
#                  'Panama',
#   'name': 'United States Government Establishment',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'UPLD',
#   'description': 'an extensive interior region of high land with low to '
#                  'moderate surface relief',
#   'name': 'upland',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'VAL',
#   'description': 'an elongated depression usually traversed by a stream',
#   'name': 'valley',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'VALS',
#   'description': 'elongated depressions usually traversed by a stream',
#   'name': 'valleys',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'VETF',
#   'description': 'a building or camp at which veterinary services are '
#                  'available',
#   'name': 'veterinary facility',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'VIN',
#   'description': 'a planting of grapevines',
#   'name': 'vineyard',
#   'status': 'active'},
#  {'category': 'V',
#   'code': 'VINS',
#   'description': 'plantings of grapevines',
#   'name': 'vineyards',
#   'status': 'active'},
#  {'category': 'T',
#   'code': 'VLC',
#   'description': 'a conical elevation composed of volcanic materials with a '
#                  'crater at the top',
#   'name': 'volcano',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WAD',
#   'description': 'a valley or ravine, bounded by relatively steep banks, which '
#                  'in the rainy season becomes a watercourse; found primarily '
#                  'in North Africa and the Middle East',
#   'name': 'wadi',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WADB',
#   'description': 'a conspicuously curved or bent segment of a wadi',
#   'name': 'wadi bend',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WADJ',
#   'description': 'a place where two or more wadies join',
#   'name': 'wadi junction',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WADM',
#   'description': 'the lower terminus of a wadi where it widens into an '
#                  'adjoining floodplain, depression, or waterbody',
#   'name': 'wadi mouth',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WADS',
#   'description': 'valleys or ravines, bounded by relatively steep banks, which '
#                  'in the rainy season become watercourses; found primarily in '
#                  'North Africa and the Middle East',
#   'name': 'wadies',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WALL',
#   'description': 'a thick masonry structure, usually enclosing a field or '
#                  'building, or forming the side of a structure',
#   'name': 'wall',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MLWTR',
#   'description': 'a mill powered by running water',
#   'name': 'water mill',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'PMPW',
#   'description': 'a facility for pumping water from a major well or through a '
#                  'pipeline',
#   'name': 'water pumping station',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'RSVT',
#   'description': 'a contained pool or tank of water at, below, or above ground '
#                  'level',
#   'name': 'water tank',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WTRC',
#   'description': 'a natural, well-defined channel produced by flowing water, '
#                  'or an artificial channel designed to carry flowing water',
#   'name': 'watercourse',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'FLLS',
#   'description': 'a perpendicular or very steep descent of the water of a '
#                  'stream',
#   'name': 'waterfall(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WTRH',
#   'description': 'a natural hole, hollow, or small depression that contains '
#                  'water, used by man and animals, especially in arid areas',
#   'name': 'waterhole(s)',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WTRW',
#   'description': 'a facility for supplying potable water through a water '
#                  'source and a system of pumps and filtration beds',
#   'name': 'waterworks',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WEIR',
#   'description': 'a small dam in a stream, designed to raise the water level '
#                  'or to divert stream flow through a desired channel',
#   'name': 'weir(s)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WLL',
#   'description': 'a cylindrical hole, pit, or tunnel drilled or dug down to a '
#                  'depth from which water, oil, or gas can be pumped or brought '
#                  'to the surface',
#   'name': 'well',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WLLS',
#   'description': 'cylindrical holes, pits, or tunnels drilled or dug down to a '
#                  'depth from which water, oil, or gas can be pumped or brought '
#                  'to the surface',
#   'name': 'wells',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WTLD',
#   'description': 'an area subject to inundation, usually characterized by bog, '
#                  'marsh, or swamp vegetation',
#   'name': 'wetland',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'STNW',
#   'description': 'a facility for butchering whales and processing train oil',
#   'name': 'whaling station',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WHRF',
#   'description': 'a structure of open rather than solid construction along a '
#                  'shore or a bank which provides berthing for ships and '
#                  'cargo-handling facilities',
#   'name': 'wharf(-ves)',
#   'status': 'active'},
#  {'category': 'H',
#   'code': 'WHRL',
#   'description': 'a turbulent, rotating movement of water in a stream',
#   'name': 'whirlpool',
#   'status': 'active'},
#  {'category': 'L',
#   'code': 'RESW',
#   'description': 'a tract of public land reserved for the preservation of '
#                  'wildlife',
#   'name': 'wildlife reserve',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'MLWND',
#   'description': 'a mill or water pump powered by wind',
#   'name': 'windmill',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'WRCK',
#   'description': 'the site of the remains of a wrecked vessel',
#   'name': 'wreck',
#   'status': 'active'},
#  {'category': 'A',
#   'code': 'ZN',
#   'description': 'zone',
#   'name': 'zone',
#   'status': 'active'},
#  {'category': 'S',
#   'code': 'ZOO',
#   'description': 'a zoological garden or park where wild animals are kept for '
#                  'exhibition',
#   'name': 'zoo',
#   'status': 'active'}]

# %% [markdown]
# ## Excel import
#
# And now let us pull the data from template and clean them up such that they are nice and comparable to the IATI standard

# %%
import pandas as pd

# now import the sector codes from the template
excel_file_path = "../../Project_Location_Data_Template_V02.xlsx"
worksheet_name = "Location Types IATI and New"

full_df = pd.read_excel(excel_file_path, sheet_name=worksheet_name)

full_df.head()
# Out:
#        KC-Theme / Sub-Sector physical or immaterial location type  \
# 0  _Generic / Cross_Sectoral                             physical
# 1  _Generic / Cross_Sectoral                             physical
# 2  _Generic / Cross_Sectoral                             physical
# 3  _Generic / Cross_Sectoral                             physical
# 4  _Generic / Cross_Sectoral                             physical
#
#   (IATI) Location Type Code  \
# 0                      BLDG
# 1                       CMN
# 2                      EQPM
# 3                       FCL
# 4                       MFG
#
#   (IATI) Location Type Name (EN) =  project output- or intervention-related type of physical location or immaterial output- or intervention area  \
# 0                                      building(s)
# 1                     common / public community area
# 2            equipment / materials distribution area
# 3                                         facility
# 4                                            factory
#
#                       (IATI) Location Type Name (DE)  \
# 0                                            Gebäude
# 1           öffentlicher Ort zur gemeinsamen Nutzung
# 2  Ausstattung (Computer, Server, Digitalisierung...
# 3                                        Einrichtung
# 4                                             Fabrik
#
#   (IITA) Nom du type de site (FR) = type de site physique ou de zone de production ou d’intervention immatérielle lié à la production ou à l’intervention du projet  \
# 0                                      bâtiment(s)
# 1                      zone commune/commune publique
# 2     zone de distribution des équipements/matériels
# 3                                     installation
# 4                                              usine
#
#   Geodata Type IATI Category  \
# 0        point             S
# 1      polygon             L
# 2      polygon           NaN
# 3        point             S
# 4        point             S
#
#                (IATI) Location Type Description (EN)  \
# 0  a structure built for permanent use, as a hous...
# 1         an area, park or pasture for community use
# 2                                                NaN
# 3  a building or buildings housing a center, inst...
# 4  one or more buildings where goods are manufact...
#
#    (IATI) Location Type Description (FR)  Unnamed: 10  \
# 0                                    NaN          NaN
# 1                                    NaN          NaN
# 2                                    NaN          NaN
# 3                                    NaN          NaN
# 4                                    NaN          NaN
#
#   Legend on the Colouring of the different lines:   \
# 0                                             BLDG
# 1                                             DEVH
# 2                                             EQPM
# 3                                              NaN
# 4                                              NaN
#
#                                          Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0          existing IATI location type (unverändert)         NaN         NaN
# 1  already existing IATI location types whose nam...         NaN         NaN
# 2  new abbreviation for the respective location t...         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4                                                NaN         NaN         NaN
#
#   Unnamed: 15 Unnamed: 16
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %% [markdown]
# Now let us only import the relevant columns

# %%
col_list = [
    "KC-Theme / Sub-Sector",
    "physical or immaterial location type",
    "(IATI) Location Type Code",
    "(IATI) Location Type Name (EN) =  project output- or intervention-related type of physical location or immaterial output- or intervention area",
    "(IITA) Nom du type de site (FR) = type de site physique ou de zone de production ou d’intervention immatérielle lié à la production ou à l’intervention du projet",
    "(IATI) Location Type Name (DE)",
    "Geodata Type",
    "IATI Category",
    "(IATI) Location Type Description (EN)",
    "(IATI) Location Type Description (FR)",
]

excel_df = pd.read_excel(excel_file_path, sheet_name=worksheet_name, usecols=col_list)
excel_df = excel_df.rename(
    columns={
        "KC-Theme / Sub-Sector": "subsector",
        "physical or immaterial location type": "character",
        "(IATI) Location Type Code": "code",
        "(IATI) Location Type Name (EN) =  project output- or intervention-related type of physical location or immaterial output- or intervention area": "name",
        "(IITA) Nom du type de site (FR) = type de site physique ou de zone de production ou d’intervention immatérielle lié à la production ou à l’intervention du projet": "name_fr",
        "(IATI) Location Type Name (DE)": "name_de",
        "Geodata Type": "geometry",
        "IATI Category": "category",
        "(IATI) Location Type Description (EN)": "description",
        "(IATI) Location Type Description (FR)": "description_fr",
    }
)
excel_df.head()
# Out:
#                    subsector character  code  \
# 0  _Generic / Cross_Sectoral  physical  BLDG
# 1  _Generic / Cross_Sectoral  physical   CMN
# 2  _Generic / Cross_Sectoral  physical  EQPM
# 3  _Generic / Cross_Sectoral  physical   FCL
# 4  _Generic / Cross_Sectoral  physical   MFG
#
#                                       name  \
# 0                            building(s)
# 1           common / public community area
# 2  equipment / materials distribution area
# 3                               facility
# 4                                  factory
#
#                                              name_de  \
# 0                                            Gebäude
# 1           öffentlicher Ort zur gemeinsamen Nutzung
# 2  Ausstattung (Computer, Server, Digitalisierung...
# 3                                        Einrichtung
# 4                                             Fabrik
#
#                                           name_fr geometry category  \
# 0                                   bâtiment(s)      point        S
# 1                   zone commune/commune publique  polygon        L
# 2  zone de distribution des équipements/matériels  polygon      NaN
# 3                                  installation      point        S
# 4                                           usine    point        S
#
#                                          description  description_fr
# 0  a structure built for permanent use, as a hous...             NaN
# 1         an area, park or pasture for community use             NaN
# 2                                                NaN             NaN
# 3  a building or buildings housing a center, inst...             NaN
# 4  one or more buildings where goods are manufact...             NaN

# %%
# export the data frame to a json file
excel_df.to_json("../../references/kfw_location_types.json", orient="records")

# %% [markdown]
# Now that us also try out the french template

# %%
# now import the sector codes from the template
fr_excel_file_path = "../../Project_Location_Data_Template_V021_FR.xlsx"
worksheet_name = "Location Types IATI and New"

full_df = pd.read_excel(excel_file_path, sheet_name=worksheet_name)

full_df.head()
